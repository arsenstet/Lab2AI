# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

X = np.random.rand(1000, 1) * 1000
y = X.squeeze() + np.random.randn(1000) * 175

scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

scaler_y = StandardScaler()
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).squeeze()

plt.figure(figsize=(10, 6))
plt.scatter(X_scaled, y_scaled, color='blue', alpha=0.5, label='Після нормалізації')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Випадковий набір даних після нормалізації')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

#навчальна вибірка
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='green', alpha=0.4, label='Навчальна вибірка')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Навчальна вибірка')
plt.legend()
plt.show()

#тестова вибірка
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='orange', alpha=0.4, label='Тестова вибірка')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Тестова вибірка')
plt.legend()
plt.show()

# %%
k_values = range(1, 21)
mse_values = []

for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)

results = pd.DataFrame({'K': k_values, 'MSE': mse_values})
print(results)
# Out:
#      K       MSE
# 0    1  0.507904
# 1    2  0.379264
# 2    3  0.319854
# 3    4  0.300183
# 4    5  0.276373
# 5    6  0.269525
# 6    7  0.261342
# 7    8  0.260226
# 8    9  0.258423
# 9   10  0.260461
# 10  11  0.258030
# 11  12  0.256720
# 12  13  0.250613
# 13  14  0.250192
# 14  15  0.251414
# 15  16  0.250943
# 16  17  0.250720
# 17  18  0.251246
# 18  19  0.247973
# 19  20  0.248158

# %%
best_k = k_values[np.argmin(mse_values)]
print(f'Найкраще значення К: {best_k}')
# Out:
# Найкраще значення К: 19

# %%
best_knn = KNeighborsRegressor(n_neighbors=best_k)
best_knn.fit(X_train, y_train)

y_train_pred = best_knn.predict(X_train)
y_test_pred = best_knn.predict(X_test)

plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='green', alpha=0.5, label='Реальні значення (навчальна вибірка)')
plt.scatter(X_train, y_train_pred, color='yellow', alpha=0.5, label='Передбачені значення (навчальна вибірка)', marker='x')
plt.xlabel('X')
plt.ylabel('y')
plt.title(f'Навчальна вибірка: Реальні vs Передбачені значення (K = {best_k})')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='blue', alpha=0.5, label='Реальні значення (тестова вибірка)')
plt.scatter(X_test, y_test_pred, color='red', alpha=0.5, label='Передбачені значення (тестова вибірка)', marker='x')
plt.xlabel('X')
plt.ylabel('y')
plt.title(f'Тестова вибірка: Реальні vs Передбачені значення (K = {best_k})')
plt.legend()
plt.show()
